# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
year = 2019
# URL page we will scraping (see image above)
url = " https://www.pro-football-reference.com/teams/sfo/2018.htm#games::none"
# this is the HTML from the given URL
r = requests.get(url) 
urlText = r.text
soup = BeautifulSoup(urlText, 'html.parser')

# %%
df = pd.read_csv('data2019.csv',delimiter=',')
new_header = df.iloc[0] #grab the first row for the header
df = df[1:] #take the data less the header row
df.columns = new_header #set the 
l = df['Tm'].astype('int') - df['Opp'].iloc[:,1].astype('int')
l.values
# Out:
# array([14, 24,  4, 28, 13,  9, 38,  3, -3, 10, 29, -3])

# %%
df = pd.read_csv('data.csv',delimiter=',')
new_header = df.iloc[0] #grab the first row for the header
df = df[1:] #take the data less the header row
df.columns = new_header #set the 
df.head()
# Out:
# 0 Week  Day          Date        NaN       NaN NaN   OT  Rec  NaN  \
# 1    1  Sun   September 9  1:00PM ET  boxscore   L  NaN  0-1    @
# 2    2  Sun  September 16  4:05PM ET  boxscore   W  NaN  1-1  NaN
# 3    3  Sun  September 23  1:00PM ET  boxscore   L  NaN  1-2    @
# 4    4  Sun  September 30  4:25PM ET  boxscore   L  NaN  1-3    @
# 5    5  Sun     October 7  4:25PM ET  boxscore   L  NaN  1-4  NaN
#
# 0                   Opp   ...   RushY   TO 1stD TotYd PassY RushY   TO  \
# 1     Minnesota Vikings   ...      90    4   19   343   227   116    1
# 2         Detroit Lions   ...     190  NaN   25   427   329    98    1
# 3    Kansas City Chiefs   ...     178  NaN   31   384   307    77  NaN
# 4  Los Angeles Chargers   ...      76    2   21   368   242   126    1
# 5     Arizona Cardinals   ...     147    5   10   220   164    56  NaN
#
# 0 Offense Defense Sp. Tms
# 1  -12.02    2.37    1.70
# 2   10.30   -8.22    1.95
# 3   19.16  -29.69   -1.56
# 4   -2.39   -3.06    0.50
# ...

# %%
df = df.drop(11)

# %%
l = df['Tm'].astype('int') - df['Opp'].iloc[:,1].astype('int')
l.values
# Out:
# array([ -8,   3, -11,  -2, -10,  -3, -29,  -3,  31,  -4, -18, -27,   6,
#          3,  -5, -16])

# %%
df['Tm'].astype('int')
# Out:
# 1     16
# 2     30
# 3     27
# 4     27
# 5     18
# 6     30
# 7     10
# 8     15
# 9     34
# 10    23
# 12     9
# 13    16
# 14    20
# 15    26
# 16     9
# 17    32
# Name: Tm, dtype: int64

# %%
df
# Out:
# 0  Week  Day          Date        NaN       NaN  NaN   OT   Rec  NaN  \
# 1     1  Sun   September 9  1:00PM ET  boxscore    L  NaN   0-1    @
# 2     2  Sun  September 16  4:05PM ET  boxscore    W  NaN   1-1  NaN
# 3     3  Sun  September 23  1:00PM ET  boxscore    L  NaN   1-2    @
# 4     4  Sun  September 30  4:25PM ET  boxscore    L  NaN   1-3    @
# 5     5  Sun     October 7  4:25PM ET  boxscore    L  NaN   1-4  NaN
# 6     6  Mon    October 15  8:15PM ET  boxscore    L  NaN   1-5    @
# 7     7  Sun    October 21  4:25PM ET  boxscore    L  NaN   1-6  NaN
# 8     8  Sun    October 28  4:25PM ET  boxscore    L  NaN   1-7    @
# 9     9  Thu    November 1  8:20PM ET  boxscore    W  NaN   2-7  NaN
# 10   10  Mon   November 12  8:15PM ET  boxscore    L  NaN   2-8  NaN
# 11   11  NaN           NaN        NaN       NaN  NaN  NaN   NaN  NaN
# 12   12  Sun   November 25  1:00PM ET  boxscore    L  NaN   2-9    @
# 13   13  Sun    December 2  4:25PM ET  boxscore    L  NaN  2-10    @
# ...
